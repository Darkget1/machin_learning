# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df2020 = pd.read_csv('data/Machine_Learning/2020.csv',index_col=0)
df2021 = pd.read_csv('data/Machine_Learning/2021.csv',index_col=0)
df2020.head()
# Out:
#      Country name  Happiness score  upperwhisker  lowerwhisker  \
# Rank
# 1         Finland           7.8087      7.869766      7.747634
# 2         Denmark           7.6456      7.711245      7.579955
# 3     Switzerland           7.5599      7.628528      7.491272
# 4         Iceland           7.5045      7.621347      7.387653
# 5          Norway           7.4880      7.556281      7.419719
#
#       GDP per capita  Social support  Healthy life expectancy  \
# Rank
# 1          10.639267        0.954330                71.900825
# 2          10.774001        0.955991                72.402504
# 3          10.979933        0.942847                74.102448
# 4          10.772559        0.974670                73.000000
# 5          11.087804        0.952487                73.200783
#
#       Freedom to make life choices  Generosity  Dystopia
# Rank
# 1                         0.949172   -0.059482  2.762835
# 2                         0.951444    0.066202  2.432741
# 3                         0.921337    0.105911  2.350267
# 4                         0.948892    0.246944  2.460688
# 5                         0.955750    0.134533  2.168266

# %%
df2021.head()
# Out:
#      Country name  Happiness score  upperwhisker  lowerwhisker  \
# Rank
# 1         Finland            7.842         7.904         7.780
# 2         Denmark            7.620         7.687         7.552
# 3     Switzerland            7.571         7.643         7.500
# 4         Iceland            7.554         7.670         7.438
# 5     Netherlands            7.464         7.518         7.410
#
#       GDP per capita  Social support  Healthy life expectancy  \
# Rank
# 1             10.775           0.954                     72.0
# 2             10.933           0.954                     72.7
# 3             11.117           0.942                     74.4
# 4             10.878           0.983                     73.0
# 5             10.932           0.942                     72.4
#
#       Freedom to make life choices  Generosity  Dystopia
# Rank
# 1                            0.949      -0.098     3.253
# 2                            0.946       0.030     2.868
# 3                            0.919       0.025     2.839
# 4                            0.955       0.160     2.967
# 5                            0.913       0.175     2.798

# %%
df2020.drop(['upperwhisker','lowerwhisker','Dystopia'],axis=1,inplace=True)
df2021.drop(['upperwhisker','lowerwhisker','Dystopia'],axis=1,inplace=True)
df2020.head()
# Out:
#      Country name  Happiness score  GDP per capita  Social support  \
# Rank
# 1         Finland           7.8087       10.639267        0.954330
# 2         Denmark           7.6456       10.774001        0.955991
# 3     Switzerland           7.5599       10.979933        0.942847
# 4         Iceland           7.5045       10.772559        0.974670
# 5          Norway           7.4880       11.087804        0.952487
#
#       Healthy life expectancy  Freedom to make life choices  Generosity
# Rank
# 1                   71.900825                      0.949172   -0.059482
# 2                   72.402504                      0.951444    0.066202
# 3                   74.102448                      0.921337    0.105911
# 4                   73.000000                      0.948892    0.246944
# 5                   73.200783                      0.955750    0.134533

# %%
df2021.head()
# Out:
#      Country name  Happiness score  GDP per capita  Social support  \
# Rank
# 1         Finland            7.842          10.775           0.954
# 2         Denmark            7.620          10.933           0.954
# 3     Switzerland            7.571          11.117           0.942
# 4         Iceland            7.554          10.878           0.983
# 5     Netherlands            7.464          10.932           0.942
#
#       Healthy life expectancy  Freedom to make life choices  Generosity
# Rank
# 1                        72.0                         0.949      -0.098
# 2                        72.7                         0.946       0.030
# 3                        74.4                         0.919       0.025
# 4                        73.0                         0.955       0.160
# 5                        72.4                         0.913       0.175

# %%
df2020.columns=['Country','Score','GDP.per.capita','Social.support','Life.expectancy','Freedom','Generosity']
df2021.columns=['Country','Score','GDP.per.capita','Social.support','Life.expectancy','Freedom','Generosity']

# %%
df2020
# Out:
#                        Country   Score  GDP.per.capita  Social.support  \
# Rank
# 1                      Finland  7.8087       10.639267        0.954330
# 2                      Denmark  7.6456       10.774001        0.955991
# 3                  Switzerland  7.5599       10.979933        0.942847
# 4                      Iceland  7.5045       10.772559        0.974670
# 5                       Norway  7.4880       11.087804        0.952487
# ...                        ...     ...             ...             ...
# 149   Central African Republic  3.4759        6.625160        0.319460
# 150                     Rwanda  3.3123        7.600104        0.540835
# 151                   Zimbabwe  3.2992        7.865712        0.763093
# 152                South Sudan  2.8166        7.425360        0.553707
# 153                Afghanistan  2.5669        7.462861        0.470367
#
#       Life.expectancy   Freedom  Generosity
# Rank
# 1           71.900825  0.949172   -0.059482
# 2           72.402504  0.951444    0.066202
# 3           74.102448  0.921337    0.105911
# 4           73.000000  0.948892    0.246944
# 5           73.200783  0.955750    0.134533
# ...               ...       ...         ...
# 149         45.200001  0.640881    0.082410
# 150         61.098846  0.900589    0.055484
# 151         55.617260  0.711458   -0.072064
# 152         51.000000  0.451314    0.016519
# 153         52.590000  0.396573   -0.096429
#
# [153 rows x 7 columns]

# %%
df2021
# Out:
#           Country  Score  GDP.per.capita  Social.support  Life.expectancy  \
# Rank
# 1         Finland  7.842          10.775           0.954           72.000
# 2         Denmark  7.620          10.933           0.954           72.700
# 3     Switzerland  7.571          11.117           0.942           74.400
# 4         Iceland  7.554          10.878           0.983           73.000
# 5     Netherlands  7.464          10.932           0.942           72.400
# ...           ...    ...             ...             ...              ...
# 145       Lesotho  3.512           7.926           0.787           48.700
# 146      Botswana  3.467           9.782           0.784           59.269
# 147        Rwanda  3.415           7.676           0.552           61.400
# 148      Zimbabwe  3.145           7.943           0.750           56.201
# 149   Afghanistan  2.523           7.695           0.463           52.493
#
#       Freedom  Generosity
# Rank
# 1       0.949      -0.098
# 2       0.946       0.030
# 3       0.919       0.025
# 4       0.955       0.160
# 5       0.913       0.175
# ...       ...         ...
# 145     0.715      -0.131
# 146     0.824      -0.246
# 147     0.897       0.061
# 148     0.677      -0.047
# 149     0.382      -0.102
#
# [149 rows x 7 columns]

# %%
df1 = df2020.copy()

# %%
df1.drop(['Social.support','Life.expectancy','Generosity'],axis=1,inplace=True)
df1
# Out:
#                        Country   Score  GDP.per.capita   Freedom
# Rank
# 1                      Finland  7.8087       10.639267  0.949172
# 2                      Denmark  7.6456       10.774001  0.951444
# 3                  Switzerland  7.5599       10.979933  0.921337
# 4                      Iceland  7.5045       10.772559  0.948892
# 5                       Norway  7.4880       11.087804  0.955750
# ...                        ...     ...             ...       ...
# 149   Central African Republic  3.4759        6.625160  0.640881
# 150                     Rwanda  3.3123        7.600104  0.900589
# 151                   Zimbabwe  3.2992        7.865712  0.711458
# 152                South Sudan  2.8166        7.425360  0.451314
# 153                Afghanistan  2.5669        7.462861  0.396573
#
# [153 rows x 4 columns]

# %%
corr = df1[['Score','GDP.per.capita','Freedom']].corr()
corr
# Out:
#                    Score  GDP.per.capita   Freedom
# Score           1.000000        0.775374  0.590597
# GDP.per.capita  0.775374        1.000000  0.419019
# Freedom         0.590597        0.419019  1.000000

# %%
corr['Score'].sort_values(ascending=False)
# Out:
# Score             1.000000
# GDP.per.capita    0.775374
# Freedom           0.590597
# Name: Score, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.heatmap(corr,annot=True,cmap='Blues')
# Out:
# <Axes: >

# %%
df2 = df2021.copy()
df2.drop(['Social.support','Life.expectancy','Generosity'],axis=1,inplace=True)
# Out:
#                    Score  GDP.per.capita   Freedom
# Score           1.000000        0.789760  0.607753
# GDP.per.capita  0.789760        1.000000  0.432323
# Freedom         0.607753        0.432323  1.000000

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df2[['Score','GDP.per.capita','Freedom']].corr(),annot=True,cmap='PuBuGn')
# Out:
# <Axes: >

# %%
x1=df2020[['Generosity','Social.support','Score']].copy()
x1
# Out:
#       Generosity  Social.support   Score
# Rank
# 1      -0.059482        0.954330  7.8087
# 2       0.066202        0.955991  7.6456
# 3       0.105911        0.942847  7.5599
# 4       0.246944        0.974670  7.5045
# 5       0.134533        0.952487  7.4880
# ...          ...             ...     ...
# 149     0.082410        0.319460  3.4759
# 150     0.055484        0.540835  3.3123
# 151    -0.072064        0.763093  3.2992
# 152     0.016519        0.553707  2.8166
# 153    -0.096429        0.470367  2.5669
#
# [153 rows x 3 columns]

# %%
x2=df2021[['Generosity','Social.support','Score']].copy()
x2
# Out:
#       Generosity  Social.support  Score
# Rank
# 1         -0.098           0.954  7.842
# 2          0.030           0.954  7.620
# 3          0.025           0.942  7.571
# 4          0.160           0.983  7.554
# 5          0.175           0.942  7.464
# ...          ...             ...    ...
# 145       -0.131           0.787  3.512
# 146       -0.246           0.784  3.467
# 147        0.061           0.552  3.415
# 148       -0.047           0.750  3.145
# 149       -0.102           0.463  2.523
#
# [149 rows x 3 columns]

# %%
a1 = x1.corr()
plt.figure(figsize=(10,6))
sns.heatmap(a1,annot=True)
# Out:
# <Axes: >

# %%
a2=x2.corr()
plt.figure(figsize=(10,6))
sns.heatmap(a2,annot=True)
# Out:
# <Axes: >

# %%
import numpy as np
corr = df2020[['Score','GDP.per.capita','Social.support','Life.expectancy','Freedom','Generosity']].corr()
corr['Score']
# Out:
# Score              1.000000
# GDP.per.capita     0.775374
# Social.support     0.765001
# Life.expectancy    0.770316
# Freedom            0.590597
# Generosity         0.069043
# Name: Score, dtype: float64

# %%
plt.figure(figsize=(11,8))
mask = np.zeros_like(corr,dtype=bool)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(corr,mask=mask,vmin=-1,vmax=1,annot=True,cmap='RdYlBu_r',linewidths=4)
# Out:
# <Axes: >

# %%
corr = df2021[['Score','GDP.per.capita','Social.support','Life.expectancy','Freedom','Generosity']].corr()
corr['Score']
plt.figure(figsize=(11,8))
mask = np.zeros_like(corr,dtype=bool)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(corr,mask=mask,vmin=-1,vmax=1,annot=True,cmap='RdYlBu_r',linewidths=4)
# Out:
# <Axes: >

# %%
economy = df2020.loc[:,['Country','GDP.per.capita']]
economy = economy.groupby(economy.Country)['GDP.per.capita'].mean().sort_values(ascending=False)
economy = economy.rank(method='min',ascending=False)['South Korea']

social = df2020.loc[:,['Country','Social.support']]
social = social.groupby(social.Country)['Social.support'].mean().sort_values(ascending=False)
social = social.rank(method='min',ascending=False)['South Korea']

health = df2020.loc[:,['Country','Life.expectancy']]
health = health.groupby(health.Country)['Life.expectancy'].mean().sort_values(ascending=False)
health = health.rank(method='min',ascending=False)['South Korea']

free = df2020.loc[:,['Country','Freedom']]
free = free.groupby(free.Country)['Freedom'].mean().sort_values(ascending=False)
free = free.rank(method='min',ascending=False)['South Korea']

print(f'153개국 중 대한민국의\nGDP순위 : {economy.astype(np.int64)}위\n'
      f'사회적 지위 순위 : {social.astype(np.int64)}위\n'
      f'기대수명 순위 : {health.astype(np.int64)}위\n'
      f'자유도 순위 : {free.astype(np.int64)}위')
# Out:
# 153개국 중 대한민국의
# GDP순위 : 27위
# 사회적 지위 순위 : 99위
# 기대수명 순위 : 10위
# 자유도 순위 : 140위

# %%
top50 = df2021.head(50)
import seaborn as sns
sns.set_theme(style='dark')
plt.figure(figsize=(24,12))
ax=sns.scatterplot(data=top50, x='Country',y='Life.expectancy',size='GDP.per.capita',sizes=(400,1500)
                   ,hue='GDP.per.capita')
plt.xticks(rotation=90,fontsize=15,color='midnightblue')

#rotation 90도 꺽어라
plt.yticks(fontsize=15,color='midnightblue')
plt.xlabel('Count or region', size=15, color='midnightblue')
plt.xlabel('Healthy life expectancy', size=15, color='midnightblue')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.pairplot(df2020)
# Out:
# D:\machine_learning\venv\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori,association_rules
dataset = [['Milk','Cookie','Apple','Beans','Eggs','Yogurt']
           ,['Coke','Cookies','Apple','Beans','Eggs','Yogurt']
           ,['Milk','Apple','Kidney Beans','Eggs']
           ,['Milk','Orange','Corn','Beans','Yogurt']
           ,['Corn','Cookie','Cookie','Beans','Ice cream','Eggs']]
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#    Apple  Beans   Coke  Cookie  Cookies   Corn   Eggs  Ice cream  \
# 0   True   True  False    True    False  False   True      False
# 1   True   True   True   False     True  False   True      False
# 2   True  False  False   False    False  False   True      False
# 3  False   True  False   False    False   True  False      False
# 4  False   True  False    True    False   True   True       True
#
#    Kidney Beans   Milk  Orange  Yogurt
# 0         False   True   False    True
# 1         False  False   False    True
# 2          True   True   False   False
# 3         False   True    True    True
# 4         False  False   False   False

# %%
frequent_itemsets = apriori(df,min_support=0.5,use_colnames=True)
frequent_itemsets.sort_values('support',ascending=False)
# Out:
#    support         itemsets
# 1      0.8          (Beans)
# 2      0.8           (Eggs)
# 0      0.6          (Apple)
# 3      0.6           (Milk)
# 4      0.6         (Yogurt)
# 5      0.6    (Eggs, Apple)
# 6      0.6    (Eggs, Beans)
# 7      0.6  (Yogurt, Beans)

# %%
frequent_itemsets = apriori(df,min_support=0.6,use_colnames=True)
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x:len(x))
frequent_itemsets
# Out:
#    support         itemsets  length
# 0      0.6          (Apple)       1
# 1      0.8          (Beans)       1
# 2      0.8           (Eggs)       1
# 3      0.6           (Milk)       1
# 4      0.6         (Yogurt)       1
# 5      0.6    (Eggs, Apple)       2
# 6      0.6    (Eggs, Beans)       2
# 7      0.6  (Yogurt, Beans)       2

# %%
rules1 = association_rules(frequent_itemsets, metric='lift',min_threshold=0.8)
rules1
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0      (Eggs)     (Apple)                 0.8                 0.6      0.6
# 1     (Apple)      (Eggs)                 0.6                 0.8      0.6
# 2      (Eggs)     (Beans)                 0.8                 0.8      0.6
# 3     (Beans)      (Eggs)                 0.8                 0.8      0.6
# 4    (Yogurt)     (Beans)                 0.6                 0.8      0.6
# 5     (Beans)    (Yogurt)                 0.8                 0.6      0.6
#
#    confidence    lift  leverage  conviction  zhangs_metric
# 0        0.75  1.2500      0.12         1.6           1.00
# 1        1.00  1.2500      0.12         inf           0.50
# 2        0.75  0.9375     -0.04         0.8          -0.25
# 3        0.75  0.9375     -0.04         0.8          -0.25
# 4        1.00  1.2500      0.12         inf           0.50
# 5        0.75  1.2500      0.12         1.6           1.00

# %%
rules2 = association_rules(frequent_itemsets, metric='lift',min_threshold=1.2)
rules2
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0      (Eggs)     (Apple)                 0.8                 0.6      0.6
# 1     (Apple)      (Eggs)                 0.6                 0.8      0.6
# 2    (Yogurt)     (Beans)                 0.6                 0.8      0.6
# 3     (Beans)    (Yogurt)                 0.8                 0.6      0.6
#
#    confidence  lift  leverage  conviction  zhangs_metric
# 0        0.75  1.25      0.12         1.6            1.0
# 1        1.00  1.25      0.12         inf            0.5
# 2        1.00  1.25      0.12         inf            0.5
# 3        0.75  1.25      0.12         1.6            1.0
