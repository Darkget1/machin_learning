# %%
import pandas as pd
import matplotlib.font_manager as fm
font_location = 'data/Machine_learning/NanumGothic.otf'
fontprop = fm.FontProperties(fname=font_location, size=12)
drama = pd.read_csv('data/Machine_Learning/top100_kdrama.csv')
drama.head()
# Out:
#                   Name  Year of release                   Aired Date  \
# 0       Move to Heaven             2021                 May 14, 2021
# 1    Hospital Playlist             2020  Mar 12, 2020 - May 28, 2020
# 2       Flower of Evil             2020  Jul 29, 2020 - Sep 23, 2020
# 3  Hospital Playlist 2             2021  Jun 17, 2021 - Sep 16, 2021
# 4            My Mister             2018  Mar 21, 2018 - May 17, 2018
#
#                Aired On  Number of Episode         Network       Duration  \
# 0                Friday                 10        Netflix         52 min.
# 1              Thursday                 12  Netflix,  tvN   1 hr. 30 min.
# 2   Wednesday, Thursday                 16            tvN   1 hr. 10 min.
# 3              Thursday                 12  Netflix,  tvN   1 hr. 40 min.
# 4   Wednesday, Thursday                 16            tvN   1 hr. 17 min.
#
#                            Content Rating  \
# 0  18+ Restricted (violence & profanity)
# 1                15+ - Teens 15 or older
# 2                15+ - Teens 15 or older
# 3                15+ - Teens 15 or older
# 4                15+ - Teens 15 or older
#
#                                             Synopsis  \
# 0  Geu Roo is a young autistic man. He works for ...
# 1  The stories of people going through their days...
# 2  Although Baek Hee Sung is hiding a dark secret...
# 3  Everyday is extraordinary for five doctors and...
# 4  Park Dong Hoon is a middle-aged engineer who i...
#
#                                                 Cast  \
# 0  Lee Je Hoon, Tang Jun Sang, Hong Seung Hee, Ju...
# 1  Jo Jung Suk, Yoo Yeon Seok, Jung Kyung Ho, Kim...
# 2  Lee Joon Gi, Moon Chae Won, Jang Hee Jin, Seo ...
# 3  Jo Jung Suk, Yoo Yeon Seok, Jung Kyung Ho, Kim...
# 4  Lee Sun Kyun, IU, Park Ho San, Song Sae Byuk, ...
#
#                                      Genre  \
# 0                   Life,  Drama,  Family
# 1   Friendship,  Romance,  Life,  Medical
# 2  Thriller,  Romance,  Crime,  Melodrama
# 3   Friendship,  Romance,  Life,  Medical
# 4   Psychological,  Life,  Drama,  Family
#
#                                                 Tags Rank  Rating
# 0  Autism, Uncle-Nephew Relationship, Death, Sava...   #1     9.2
# 1  Strong Friendship, Multiple Mains, Best Friend...   #2     9.1
# 2  Married Couple, Deception, Suspense, Family Se...   #3     9.1
# 3  Workplace, Strong Friendship, Best Friends, Mu...   #4     9.1
# 4  Age Gap, Nice Male Lead, Strong Female Lead, H...   #5     9.1

# %%
drama.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               100 non-null    object
#  1   Year of release    100 non-null    int64
#  2   Aired Date         100 non-null    object
#  3   Aired On           100 non-null    object
#  4   Number of Episode  100 non-null    int64
#  5   Network            100 non-null    object
#  6   Duration           100 non-null    object
#  7   Content Rating     100 non-null    object
#  8   Synopsis           100 non-null    object
#  9   Cast               100 non-null    object
#  10  Genre              100 non-null    object
#  11  Tags               100 non-null    object
#  12  Rank               100 non-null    object
#  13  Rating             100 non-null    float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 11.1+ KB

# %%
#숫자로 되있는것만 출력
drama.describe()
# Out:
#        Year of release  Number of Episode      Rating
# count       100.000000         100.000000  100.000000
# mean       2017.970000          19.070000    8.723000
# std           2.869044          12.378096    0.174573
# min        2003.000000           6.000000    8.500000
# 25%        2017.000000          16.000000    8.600000
# 50%        2019.000000          16.000000    8.700000
# 75%        2020.000000          20.000000    8.800000
# max        2021.000000         100.000000    9.200000

# %%
drama['Rating'].describe()
# Out:
# count    100.000000
# mean       8.723000
# std        0.174573
# min        8.500000
# 25%        8.600000
# 50%        8.700000
# 75%        8.800000
# max        9.200000
# Name: Rating, dtype: float64

# %%
drama[['Year of release','Rating']]
# Out:
#     Year of release  Rating
# 0              2021     9.2
# 1              2020     9.1
# 2              2020     9.1
# 3              2021     9.1
# 4              2018     9.1
# ..              ...     ...
# 95             2019     8.5
# 96             2019     8.5
# 97             2019     8.5
# 98             2017     8.5
# 99             2017     8.5
#
# [100 rows x 2 columns]

# %%
d = drama.sort_values('Number of Episode',ascending=False)
d.head(5)
# Out:
#                     Name  Year of release                   Aired Date  \
# 81            Once Again             2020  Mar 28, 2020 - Sep 13, 2020
# 64   Jewel in the Palace             2003  Sep 15, 2003 - Mar 23, 2004
# 65  My Father is Strange             2017  Mar  4, 2017 - Aug 27, 2017
# 71            Empress Ki             2013  Oct 28, 2013 - Apr 29, 2014
# 32    Six Flying Dragons             2015  Oct  5, 2015 - Mar 22, 2016
#
#              Aired On  Number of Episode Network      Duration  \
# 81   Saturday, Sunday                100   KBS2        35 min.
# 64    Monday, Tuesday                 54    MBC   1 hr. 5 min.
# 65   Saturday, Sunday                 52   KBS2   1 hr. 6 min.
# 71    Monday, Tuesday                 51    MBC   1 hr. 5 min.
# 32    Monday, Tuesday                 50    SBS        60 min.
#
#               Content Rating  \
# 81  15+ - Teens 15 or older
# 64  13+ - Teens 13 or older
# 65  15+ - Teens 15 or older
# 71  15+ - Teens 15 or older
# 32  15+ - Teens 15 or older
#
#                                              Synopsis  \
# 81  "Once Again" is the story of the eventful Song...
# 64  About 500 years ago during the time of Chosun ...
# 65  This drama is about a family that lives on the...
# 71  Genghis Khan built an empire that spanned vast...
# 32  A fiction historical drama about the ambition,...
#
#                                                  Cast  \
# 81  Chun Ho Jin, Cha Hwa Yun, Lee Jung Eun, Oh Dae...
# 64  Lee Young Ae, Ji Jin Hee, Hong Ri Na, Im Ho, Y...
# 65  Kim Yeong Cheol, Kim Hae Sook, Ryu Soo Young, ...
# 71  Ha Ji Won, Ji Chang Wook, Joo Jin Mo, Baek Jin...
# 32  Yoo Ah In, Kim Myung Min, Shin Se Kyung, Byun ...
#
#                                             Genre  \
# 81             Comedy,  Romance,  Drama,  Family
# 64         Food,  Historical,  Romance,  Medical
# 65             Comedy,  Romance,  Drama,  Family
# 71  Historical,  Romance,  Melodrama,  Political
# 32       Action,  Historical,  Drama,  Political
#
#                                                  Tags Rank  Rating
# 81  Divorce, Family Relationship, Multiple Couples...  #82     8.6
# 64  Cooking, Strong Female Lead, Royal Rules And E...  #65     8.6
# 65  Family Secret, Sisterhood, Eccentric Female Le...  #66     8.6
# 71  Smart Female Lead, Strong Female Lead, Power S...  #72     8.6
# 32  Revolution, Power Struggle, Political Intrigue...  #33     8.8

# %%
d = drama.sort_values('Year of release')
d.head()
# Out:
#                    Name  Year of release                   Aired Date  \
# 64  Jewel in the Palace             2003  Sep 15, 2003 - Mar 23, 2004
# 62      The Bridal Mask             2012  May 30, 2012 - Sep  6, 2012
# 88           Reply 1997             2012  Jul 24, 2012 - Sep 18, 2012
# 80     The Master's Sun             2013  Aug  7, 2013 - Oct  3, 2013
# 74           Cruel City             2013  May 27, 2013 - Jul 30, 2013
#
#                 Aired On  Number of Episode Network      Duration  \
# 64       Monday, Tuesday                 54    MBC   1 hr. 5 min.
# 62   Wednesday, Thursday                 28   KBS2   1 hr. 5 min.
# 88               Tuesday                 16    tvN        60 min.
# 80   Wednesday, Thursday                 17    SBS   1 hr. 2 min.
# 74       Monday, Tuesday                 20   jTBC        60 min.
#
#               Content Rating  \
# 64  13+ - Teens 13 or older
# 62  15+ - Teens 15 or older
# 88  15+ - Teens 15 or older
# 80  15+ - Teens 15 or older
# 74  15+ - Teens 15 or older
#
#                                              Synopsis  \
# 64  About 500 years ago during the time of Chosun ...
# 62  Lee Kang To is an ambitious and callous Korean...
# 88  Set in the 1990's, the drama centers around a ...
# 80  Joo Joong Won is the stingy and greedy CEO of ...
# 74  Portrays the cruel life of the drug cartels an...
#
#                                                  Cast  \
# 64  Lee Young Ae, Ji Jin Hee, Hong Ri Na, Im Ho, Y...
# 62  Joo Won, Jin Se Yeon, Park Ki Woong, Han Chae ...
# 88  Jung Eun Ji, Seo In Guk, Hoya, Shin So Yool, E...
# 80  Gong Hyo Jin, So Ji Sub, Seo In Guk, Kim Yoo R...
# 74  Jung Kyung Ho, Nam Gyu Ri, Lee Jae Yoon, Son C...
#
#                                          Genre  \
# 64      Food,  Historical,  Romance,  Medical
# 62  Action,  Historical,  Romance,  Political
# 88           Comedy,  Romance,  Life,  Family
# 80   Horror,  Comedy,  Romance,  Supernatural
# 74        Action,  Thriller,  Romance,  Crime
#
#                                                  Tags Rank  Rating
# 64  Cooking, Strong Female Lead, Royal Rules And E...  #65     8.6
# 62  Japanese Colonial Rule, Hidden Identity, Reven...  #63     8.6
# 88  Childhood Friends, High School, 1990s, Strong ...  #89     8.5
# 80  Ghost, Eccentric Female Lead, Rich Male Lead, ...  #81     8.6
# 74  Badass Male Lead, Gang, Bromance, Strong Femal...  #75     8.6

# %%
count =drama['Year of release'].value_counts()
count
pd.DataFrame(count)
# Out:
#                  count
# Year of release
# 2021                19
# 2020                17
# 2017                16
# 2019                15
# 2018                10
# 2016                 8
# 2013                 5
# 2014                 4
# 2015                 3
# 2012                 2
# 2003                 1

# %%
count =drama['Rating'].value_counts(ascending=True)
count
pd.DataFrame(count)
# Out:
#         count
# Rating
# 9.2         1
# 9.1         5
# 8.9         5
# 9.0         9
# 8.5        15
# 8.8        16
# 8.7        24
# 8.6        25

# %%
count = drama['Network'].value_counts()
pd.DataFrame(count)
# Out:
#                  count
# Network
# tvN                 19
# SBS                 17
# Netflix,  tvN       16
# KBS2                10
# MBC                  9
# jTBC                 8
# Netflix              7
# OCN                  7
# Netflix,  SBS        2
# jTBC,  Netflix       2
# Netflix,  OCN        1
# jTBC,  Viki          1
# KBS2,  Netflix       1

# %%
drama[['Name','Rating']]
# Out:
#                              Name  Rating
# 0                  Move to Heaven     9.2
# 1               Hospital Playlist     9.1
# 2                  Flower of Evil     9.1
# 3             Hospital Playlist 2     9.1
# 4                       My Mister     9.1
# ..                            ...     ...
# 95                       Vagabond     8.5
# 96                    Doctor John     8.5
# 97       When the Camellia Blooms     8.5
# 98  Because This Is My First Life     8.5
# 99               Fight For My Way     8.5
#
# [100 rows x 2 columns]

# %%
d = drama['Number of Episode']==drama['Number of Episode'].max()
drama[d]
# Out:
#           Name  Year of release                   Aired Date  \
# 81  Once Again             2020  Mar 28, 2020 - Sep 13, 2020
#
#              Aired On  Number of Episode Network Duration  \
# 81   Saturday, Sunday                100   KBS2   35 min.
#
#               Content Rating  \
# 81  15+ - Teens 15 or older
#
#                                              Synopsis  \
# 81  "Once Again" is the story of the eventful Song...
#
#                                                  Cast  \
# 81  Chun Ho Jin, Cha Hwa Yun, Lee Jung Eun, Oh Dae...
#
#                                  Genre  \
# 81  Comedy,  Romance,  Drama,  Family
#
#                                                  Tags Rank  Rating
# 81  Divorce, Family Relationship, Multiple Couples...  #82     8.6

# %%
d = drama['Number of Episode']==drama['Number of Episode'].min()
drama[d][['Name','Number of Episode']]
# Out:
#                          Name  Number of Episode
# 16                    Kingdom                  6
# 23                       D.P.                  6
# 24                    Kingdom                  6
# 45  Arthdal Chronicles Part 2                  6
# 47  Arthdal Chronicles Part 3                  6
# 92  Arthdal Chronicles Part 1                  6

# %%
d = drama['Network'].str.contains('Netflix')
drama[d].head()
# Out:
#                        Name  Year of release                   Aired Date  \
# 0            Move to Heaven             2021                 May 14, 2021
# 1         Hospital Playlist             2020  Mar 12, 2020 - May 28, 2020
# 3       Hospital Playlist 2             2021  Jun 17, 2021 - Sep 16, 2021
# 5           Prison Playbook             2017  Nov 22, 2017 - Jan 18, 2018
# 7  It's Okay to Not Be Okay             2020  Jun 20, 2020 - Aug  9, 2020
#
#                Aired On  Number of Episode         Network       Duration  \
# 0                Friday                 10        Netflix         52 min.
# 1              Thursday                 12  Netflix,  tvN   1 hr. 30 min.
# 3              Thursday                 12  Netflix,  tvN   1 hr. 40 min.
# 5   Wednesday, Thursday                 16  Netflix,  tvN   1 hr. 32 min.
# 7      Saturday, Sunday                 16  Netflix,  tvN   1 hr. 15 min.
#
#                            Content Rating  \
# 0  18+ Restricted (violence & profanity)
# 1                15+ - Teens 15 or older
# 3                15+ - Teens 15 or older
# 5                15+ - Teens 15 or older
# 7                15+ - Teens 15 or older
#
#                                             Synopsis  \
# 0  Geu Roo is a young autistic man. He works for ...
# 1  The stories of people going through their days...
# 3  Everyday is extraordinary for five doctors and...
# 5  Kim Je Hyuk, a famous baseball player, is arre...
# 7  Moon Gang Tae is a community health worker at ...
#
#                                                 Cast  \
# 0  Lee Je Hoon, Tang Jun Sang, Hong Seung Hee, Ju...
# 1  Jo Jung Suk, Yoo Yeon Seok, Jung Kyung Ho, Kim...
# 3  Jo Jung Suk, Yoo Yeon Seok, Jung Kyung Ho, Kim...
# 5  Park Hae Soo, Jung Kyung Ho, Krystal Jung, Im ...
# 7  Kim Soo Hyun, Seo Yea Ji, Oh Jung Se, Park Gyu...
#
#                                        Genre  \
# 0                     Life,  Drama,  Family
# 1     Friendship,  Romance,  Life,  Medical
# 3     Friendship,  Romance,  Life,  Medical
# 5             Comedy,  Crime,  Life,  Drama
# 7  Psychological,  Comedy,  Romance,  Drama
#
#                                                 Tags Rank  Rating
# 0  Autism, Uncle-Nephew Relationship, Death, Sava...   #1     9.2
# 1  Strong Friendship, Multiple Mains, Best Friend...   #2     9.1
# 3  Workplace, Strong Friendship, Best Friends, Mu...   #4     9.1
# 5  Prison, Bromance, Wrongfully Accused, Life Les...   #6     9.1
# 7  Sibling Relationship, Melodrama, Mental Health...   #8     9.0

# %%
d = drama['Network'].str.contains('Netflix | tvN')
drama[d].head()
# Out:
#                        Name  Year of release                   Aired Date  \
# 0            Move to Heaven             2021                 May 14, 2021
# 1         Hospital Playlist             2020  Mar 12, 2020 - May 28, 2020
# 3       Hospital Playlist 2             2021  Jun 17, 2021 - Sep 16, 2021
# 5           Prison Playbook             2017  Nov 22, 2017 - Jan 18, 2018
# 7  It's Okay to Not Be Okay             2020  Jun 20, 2020 - Aug  9, 2020
#
#                Aired On  Number of Episode         Network       Duration  \
# 0                Friday                 10        Netflix         52 min.
# 1              Thursday                 12  Netflix,  tvN   1 hr. 30 min.
# 3              Thursday                 12  Netflix,  tvN   1 hr. 40 min.
# 5   Wednesday, Thursday                 16  Netflix,  tvN   1 hr. 32 min.
# 7      Saturday, Sunday                 16  Netflix,  tvN   1 hr. 15 min.
#
#                            Content Rating  \
# 0  18+ Restricted (violence & profanity)
# 1                15+ - Teens 15 or older
# 3                15+ - Teens 15 or older
# 5                15+ - Teens 15 or older
# 7                15+ - Teens 15 or older
#
#                                             Synopsis  \
# 0  Geu Roo is a young autistic man. He works for ...
# 1  The stories of people going through their days...
# 3  Everyday is extraordinary for five doctors and...
# 5  Kim Je Hyuk, a famous baseball player, is arre...
# 7  Moon Gang Tae is a community health worker at ...
#
#                                                 Cast  \
# 0  Lee Je Hoon, Tang Jun Sang, Hong Seung Hee, Ju...
# 1  Jo Jung Suk, Yoo Yeon Seok, Jung Kyung Ho, Kim...
# 3  Jo Jung Suk, Yoo Yeon Seok, Jung Kyung Ho, Kim...
# 5  Park Hae Soo, Jung Kyung Ho, Krystal Jung, Im ...
# 7  Kim Soo Hyun, Seo Yea Ji, Oh Jung Se, Park Gyu...
#
#                                        Genre  \
# 0                     Life,  Drama,  Family
# 1     Friendship,  Romance,  Life,  Medical
# 3     Friendship,  Romance,  Life,  Medical
# 5             Comedy,  Crime,  Life,  Drama
# 7  Psychological,  Comedy,  Romance,  Drama
#
#                                                 Tags Rank  Rating
# 0  Autism, Uncle-Nephew Relationship, Death, Sava...   #1     9.2
# 1  Strong Friendship, Multiple Mains, Best Friend...   #2     9.1
# 3  Workplace, Strong Friendship, Best Friends, Mu...   #4     9.1
# 5  Prison, Bromance, Wrongfully Accused, Life Les...   #6     9.1
# 7  Sibling Relationship, Melodrama, Mental Health...   #8     9.0

# %%
target = ['Netflix','tvN']
d = drama['Network'].map(lambda x: all(string in x for string in target))
drama[d].head()
# Out:
#                         Name  Year of release                   Aired Date  \
# 1          Hospital Playlist             2020  Mar 12, 2020 - May 28, 2020
# 3        Hospital Playlist 2             2021  Jun 17, 2021 - Sep 16, 2021
# 5            Prison Playbook             2017  Nov 22, 2017 - Jan 18, 2018
# 7   It's Okay to Not Be Okay             2020  Jun 20, 2020 - Aug  9, 2020
# 11                 Navillera             2021  Mar 22, 2021 - Apr 27, 2021
#
#                 Aired On  Number of Episode         Network       Duration  \
# 1               Thursday                 12  Netflix,  tvN   1 hr. 30 min.
# 3               Thursday                 12  Netflix,  tvN   1 hr. 40 min.
# 5    Wednesday, Thursday                 16  Netflix,  tvN   1 hr. 32 min.
# 7       Saturday, Sunday                 16  Netflix,  tvN   1 hr. 15 min.
# 11       Monday, Tuesday                 12  Netflix,  tvN    1 hr. 5 min.
#
#               Content Rating  \
# 1   15+ - Teens 15 or older
# 3   15+ - Teens 15 or older
# 5   15+ - Teens 15 or older
# 7   15+ - Teens 15 or older
# 11  15+ - Teens 15 or older
#
#                                              Synopsis  \
# 1   The stories of people going through their days...
# 3   Everyday is extraordinary for five doctors and...
# 5   Kim Je Hyuk, a famous baseball player, is arre...
# 7   Moon Gang Tae is a community health worker at ...
# 11  A 70-year-old with a dream and a 23-year-old w...
#
#                                                  Cast  \
# 1   Jo Jung Suk, Yoo Yeon Seok, Jung Kyung Ho, Kim...
# 3   Jo Jung Suk, Yoo Yeon Seok, Jung Kyung Ho, Kim...
# 5   Park Hae Soo, Jung Kyung Ho, Krystal Jung, Im ...
# 7   Kim Soo Hyun, Seo Yea Ji, Oh Jung Se, Park Gyu...
# 11  Park In Hwan, Song Kang, Na Moon Hee, Hong Seu...
#
#                                         Genre  \
# 1      Friendship,  Romance,  Life,  Medical
# 3      Friendship,  Romance,  Life,  Medical
# 5              Comedy,  Crime,  Life,  Drama
# 7   Psychological,  Comedy,  Romance,  Drama
# 11        Friendship,  Life,  Drama,  Family
#
#                                                  Tags Rank  Rating
# 1   Strong Friendship, Multiple Mains, Best Friend...   #2     9.1
# 3   Workplace, Strong Friendship, Best Friends, Mu...   #4     9.1
# 5   Prison, Bromance, Wrongfully Accused, Life Les...   #6     9.1
# 7   Sibling Relationship, Melodrama, Mental Health...   #8     9.0
# 11  Ballet, Dream, Life Lesson, Old-Young Generati...  #12     9.0

# %%
target = ['Netflix','tvN']
d = drama['Network'].map(lambda x:all(string in x for string in target))
drama[d].head()
# Out:
#                         Name  Year of release                   Aired Date  \
# 1          Hospital Playlist             2020  Mar 12, 2020 - May 28, 2020
# 3        Hospital Playlist 2             2021  Jun 17, 2021 - Sep 16, 2021
# 5            Prison Playbook             2017  Nov 22, 2017 - Jan 18, 2018
# 7   It's Okay to Not Be Okay             2020  Jun 20, 2020 - Aug  9, 2020
# 11                 Navillera             2021  Mar 22, 2021 - Apr 27, 2021
#
#                 Aired On  Number of Episode         Network       Duration  \
# 1               Thursday                 12  Netflix,  tvN   1 hr. 30 min.
# 3               Thursday                 12  Netflix,  tvN   1 hr. 40 min.
# 5    Wednesday, Thursday                 16  Netflix,  tvN   1 hr. 32 min.
# 7       Saturday, Sunday                 16  Netflix,  tvN   1 hr. 15 min.
# 11       Monday, Tuesday                 12  Netflix,  tvN    1 hr. 5 min.
#
#               Content Rating  \
# 1   15+ - Teens 15 or older
# 3   15+ - Teens 15 or older
# 5   15+ - Teens 15 or older
# 7   15+ - Teens 15 or older
# 11  15+ - Teens 15 or older
#
#                                              Synopsis  \
# 1   The stories of people going through their days...
# 3   Everyday is extraordinary for five doctors and...
# 5   Kim Je Hyuk, a famous baseball player, is arre...
# 7   Moon Gang Tae is a community health worker at ...
# 11  A 70-year-old with a dream and a 23-year-old w...
#
#                                                  Cast  \
# 1   Jo Jung Suk, Yoo Yeon Seok, Jung Kyung Ho, Kim...
# 3   Jo Jung Suk, Yoo Yeon Seok, Jung Kyung Ho, Kim...
# 5   Park Hae Soo, Jung Kyung Ho, Krystal Jung, Im ...
# 7   Kim Soo Hyun, Seo Yea Ji, Oh Jung Se, Park Gyu...
# 11  Park In Hwan, Song Kang, Na Moon Hee, Hong Seu...
#
#                                         Genre  \
# 1      Friendship,  Romance,  Life,  Medical
# 3      Friendship,  Romance,  Life,  Medical
# 5              Comedy,  Crime,  Life,  Drama
# 7   Psychological,  Comedy,  Romance,  Drama
# 11        Friendship,  Life,  Drama,  Family
#
#                                                  Tags Rank  Rating
# 1   Strong Friendship, Multiple Mains, Best Friend...   #2     9.1
# 3   Workplace, Strong Friendship, Best Friends, Mu...   #4     9.1
# 5   Prison, Bromance, Wrongfully Accused, Life Les...   #6     9.1
# 7   Sibling Relationship, Melodrama, Mental Health...   #8     9.0
# 11  Ballet, Dream, Life Lesson, Old-Young Generati...  #12     9.0

# %%
d=(drama['Year of release']>=2015) & (drama['Year of release']<=2020)
drama[d].head()
# Out:
#                 Name  Year of release                   Aired Date  \
# 1  Hospital Playlist             2020  Mar 12, 2020 - May 28, 2020
# 2     Flower of Evil             2020  Jul 29, 2020 - Sep 23, 2020
# 4          My Mister             2018  Mar 21, 2018 - May 17, 2018
# 5    Prison Playbook             2017  Nov 22, 2017 - Jan 18, 2018
# 6         Reply 1988             2015  Nov  6, 2015 - Jan 16, 2016
#
#                Aired On  Number of Episode         Network       Duration  \
# 1              Thursday                 12  Netflix,  tvN   1 hr. 30 min.
# 2   Wednesday, Thursday                 16            tvN   1 hr. 10 min.
# 4   Wednesday, Thursday                 16            tvN   1 hr. 17 min.
# 5   Wednesday, Thursday                 16  Netflix,  tvN   1 hr. 32 min.
# 6      Friday, Saturday                 20            tvN   1 hr. 40 min.
#
#              Content Rating  \
# 1  15+ - Teens 15 or older
# 2  15+ - Teens 15 or older
# 4  15+ - Teens 15 or older
# 5  15+ - Teens 15 or older
# 6  15+ - Teens 15 or older
#
#                                             Synopsis  \
# 1  The stories of people going through their days...
# 2  Although Baek Hee Sung is hiding a dark secret...
# 4  Park Dong Hoon is a middle-aged engineer who i...
# 5  Kim Je Hyuk, a famous baseball player, is arre...
# 6  Five childhood friends, who all live in the sa...
#
#                                                 Cast  \
# 1  Jo Jung Suk, Yoo Yeon Seok, Jung Kyung Ho, Kim...
# 2  Lee Joon Gi, Moon Chae Won, Jang Hee Jin, Seo ...
# 4  Lee Sun Kyun, IU, Park Ho San, Song Sae Byuk, ...
# 5  Park Hae Soo, Jung Kyung Ho, Krystal Jung, Im ...
# 6  Lee Hye Ri, Go Kyung Pyo, Ryu Joon Yeol, Park ...
#
#                                      Genre  \
# 1   Friendship,  Romance,  Life,  Medical
# 2  Thriller,  Romance,  Crime,  Melodrama
# 4   Psychological,  Life,  Drama,  Family
# 5           Comedy,  Crime,  Life,  Drama
# 6       Comedy,  Romance,  Youth,  Family
#
#                                                 Tags Rank  Rating
# 1  Strong Friendship, Multiple Mains, Best Friend...   #2     9.1
# 2  Married Couple, Deception, Suspense, Family Se...   #3     9.1
# 4  Age Gap, Nice Male Lead, Strong Female Lead, H...   #5     9.1
# 5  Prison, Bromance, Wrongfully Accused, Life Les...   #6     9.1
# 6  Neighbors, Slice Of Life, Childhood Friends, M...   #7     9.0

# %%
col = ['Aired Date','Duration','Synopsis','Cast','Tags']
newdrama = drama.drop(col,axis=1)
newdrama.columns
# Out:
# Index(['Name', 'Year of release', 'Aired On', 'Number of Episode', 'Network',
#        'Content Rating', 'Genre', 'Rank', 'Rating'],
#       dtype='object')

# %%
newdrama.columns=['이름','개봉년도','요일','에피소드수','네트워크','등급','장르','순위','평점']
newdrama.columns
# Out:
# Index(['이름', '개봉년도', '요일', '에피소드수', '네트워크', '등급', '장르', '순위', '평점'], dtype='object')

# %%
newdrama['장르갯수'] = newdrama['장르'].str.count(',')+1
#,단위로 갯수를 샌다 a,b,c 이면 ,는 2개 이므로 실제 갯수는 +1해야함
newdrama.head(100)
# Out:
#                                이름  개봉년도                    요일  에피소드수  \
# 0                  Move to Heaven  2021                Friday     10
# 1               Hospital Playlist  2020              Thursday     12
# 2                  Flower of Evil  2020   Wednesday, Thursday     16
# 3             Hospital Playlist 2  2021              Thursday     12
# 4                       My Mister  2018   Wednesday, Thursday     16
# ..                            ...   ...                   ...    ...
# 95                       Vagabond  2019      Friday, Saturday     16
# 96                    Doctor John  2019      Friday, Saturday     32
# 97       When the Camellia Blooms  2019   Wednesday, Thursday     40
# 98  Because This Is My First Life  2017       Monday, Tuesday     16
# 99               Fight For My Way  2017       Monday, Tuesday     16
#
#                네트워크                                      등급  \
# 0          Netflix   18+ Restricted (violence & profanity)
# 1    Netflix,  tvN                 15+ - Teens 15 or older
# 2              tvN                 15+ - Teens 15 or older
# 3    Netflix,  tvN                 15+ - Teens 15 or older
# 4              tvN                 15+ - Teens 15 or older
# ..              ...                                     ...
# 95   Netflix,  SBS                 15+ - Teens 15 or older
# 96             SBS                 15+ - Teens 15 or older
# 97  KBS2,  Netflix                 15+ - Teens 15 or older
# 98             tvN                 15+ - Teens 15 or older
# 99            KBS2                 15+ - Teens 15 or older
#
#                                                장르    순위   평점  장르갯수
# 0                          Life,  Drama,  Family     #1  9.2     3
# 1          Friendship,  Romance,  Life,  Medical     #2  9.1     4
# 2         Thriller,  Romance,  Crime,  Melodrama     #3  9.1     4
# 3          Friendship,  Romance,  Life,  Medical     #4  9.1     4
# 4          Psychological,  Life,  Drama,  Family     #5  9.1     4
# ..                                            ...   ...  ...   ...
# 95           Action,  Thriller,  Mystery,  Crime    #96  8.5     4
# 96            Mystery,  Romance,  Life,  Medical    #97  8.5     4
# 97  Thriller,  Comedy,  Romance,  Drama,  Family    #98  8.5     5
# 98               Comedy,  Romance,  Life,  Drama    #99  8.5     4
# 99          Business,  Comedy,  Romance,  Sports   #100  8.5     4
#
# [100 rows x 10 columns]

# %%
d = newdrama.groupby('개봉년도')['평점'].mean()
pd.DataFrame(d)
# Out:
#             평점
# 개봉년도
# 2003  8.600000
# 2012  8.550000
# 2013  8.580000
# 2014  8.700000
# 2015  8.833333
# 2016  8.750000
# 2017  8.662500
# 2018  8.790000
# 2019  8.646667
# 2020  8.752941
# 2021  8.810526

# %%
d = newdrama.groupby('개봉년도')['이름'].count()
pd.DataFrame(d)
# Out:
#       이름
# 개봉년도
# 2003   1
# 2012   2
# 2013   5
# 2014   4
# 2015   3
# 2016   8
# 2017  16
# 2018  10
# 2019  15
# 2020  17
# 2021  19

# %%
d = newdrama.groupby(['개봉년도','평점'])['이름'].count()
pd.DataFrame(d)
# Out:
#           이름
# 개봉년도 평점
# 2003 8.6   1
# 2012 8.5   1
#      8.6   1
# 2013 8.5   1
#      8.6   4
# 2014 8.6   2
#      8.7   1
#      8.9   1
# 2015 8.7   1
#      8.8   1
#      9.0   1
# 2016 8.6   1
#      8.7   4
#      8.8   2
#      9.0   1
# 2017 8.5   3
#      8.6   6
#      8.7   5
#      8.9   1
#      9.1   1
# 2018 8.5   1
#      8.6   2
#      8.7   1
#      8.8   2
#      8.9   2
#      9.0   1
#      9.1   1
# 2019 8.5   5
#      8.6   2
#      8.7   6
#      8.8   1
#      9.0   1
# 2020 8.5   2
#      8.6   5
#      8.7   3
#      8.8   2
#      8.9   1
#      9.0   2
#      9.1   2
# 2021 8.5   2
#      8.6   1
#      8.7   3
#      8.8   8
#      9.0   3
#      9.1   1
#      9.2   1

# %%
import matplotlib.pyplot as plt
import  numpy as np
data = newdrama.groupby('개봉년도')['평점'].mean()
plt.figure(figsize=(16,10))
plt.plot(data,color='r',marker='o')
plt.xticks(np.arange(2003,2022))
plt.xlabel('개봉년도',fontproperties=fontprop)
plt.ylabel('평점의 평균',fontproperties=fontprop)
plt.grid()
plt.show()

# %%
import matplotlib

# font_location = 'C:/Windows/Fonts/NanumMyeongjo.ttf' # For Windows
# font_name = fm.FontProperties(fname=font_location).get_name()
# matplotlib.rc('font', family=font_name)

top5 =newdrama['개봉년도'].value_counts().head(5)
plt.figure(figsize=(16,10))
plt.bar(top5.index,top5,color='g')
plt.xlabel('개봉년도',fontproperties=fontprop)
plt.ylabel('장르개수',fontproperties=fontprop)
plt.title('개봉년도별 장르개수 TOP5',fontproperties=fontprop)
plt.grid()
plt.show()

# %%
year_Count=newdrama.groupby('개봉년도').size()
plt.figure(figsize=(16,10))
plt.plot(year_Count,color='r',marker='o')
plt.bar(year_Count.index,year_Count,color='g')
plt.xticks(np.arange(2003,2022))
plt.xlabel('Year of elease')
plt.ylabel('Count')
plt.grid()
plt.show()

# %%
from collections import Counter
#순수 문자열로 변환
newdrama['장르'] = newdrama['장르'].str.strip()
genre_list = list()
for genres in newdrama['장르'].to_list():
    genres = genres.split(",")
    for gen in genres:
        genre_list.append(gen)
genre_df = pd.DataFrame.from_dict(Counter(genre_list),orient='index').rename(columns = {0:'Count'})
genre_df.sort_values('Count',ascending=False,inplace=True)
genre_df.head(37)
# Out:
#                  Count
#   Drama             51
#   Romance           46
#   Mystery           25
# Thriller            21
#   Comedy            21
# Action              19
#   Life              15
# Comedy              15
#   Family            15
#   Melodrama         14
#   Crime             13
#   Supernatural      12
#   Thriller          12
#   Fantasy           11
#   Political         10
# Friendship           9
# Mystery              8
#   Law                8
#   Historical         7
# Historical           7
#   Medical            7
#   Psychological      6
# Psychological        6
#   Sci-Fi             5
#   Youth              5
#   Sports             4
#   Horror             4
# Romance              3
# Horror               3
# Life                 3
# Military             2
#   Business           2
#   School             2
# Business             2
#   Military           1
# Drama                1
# Food                 1

# %%
#ex6

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 2
#       1 tvN = drama['Network']=='tvN'
# ----> 2 drama[tvN].head(5)[['Name','Newtwork']]
#
# File D:\machine_learning\venv\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File D:\machine_learning\venv\Lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# File D:\machine_learning\venv\Lib\site-packages\pandas\core\indexes\base.py:5941, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5938     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5940 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5941 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Newtwork'] not in index"
