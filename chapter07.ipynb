# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.randn(8,3), columns=['C1','C2','C3'])
df.loc[2,'C2'] = np.nan
df.loc[3,'C2']= np.nan
df.info()

# %%
df.isnull().sum()
# Out:
# C1    0
# C2    2
# C3    0
# dtype: int64

# %%
data = {'학번':range(2000,2010),'성적':[85,95,75,70,100,100,95,85,80,85],'전공':['컴퓨터공학','컴퓨터공학',
                                                                               '화학공학','기계공학'
                                                                               ,'전자공학','수학교육'
                                                                               ,'건축공학','항곡시스템공학'
                                                                               ,'컴퓨터공학',np.nan]}
df=pd.DataFrame(data)
df = df.astype({'학번':object})
df.describe()
# Out:
#                성적
# count   10.000000
# mean    87.000000
# std     10.327956
# min     70.000000
# 25%     81.250000
# 50%     85.000000
# 75%     95.000000
# max    100.000000

# %%
df.describe(include='object')
# Out:
#           학번     전공
# count     10      9
# unique    10      7
# top     2000  컴퓨터공학
# freq       1      3

# %%
df.hist(figsize=(20,10),grid=False,layout=(2,4),bins=30)
# Out:
# array([[<Axes: title={'center': '성적'}>, <Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >, <Axes: >]], dtype=object)
# D:\machine_learning\venv\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   func(*args, **kwargs)
# D:\machine_learning\venv\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 51201 (\N{HANGUL SYLLABLE JEOG}) missing from current font.
#   func(*args, **kwargs)
# D:\machine_learning\venv\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# D:\machine_learning\venv\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51201 (\N{HANGUL SYLLABLE JEOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.DataFrame(np.random.randn(20,3),columns=['C1','C2','C3'])
df.loc[1,'C1']=11
df.loc[3,'C3']=-10
df
# Out:
#            C1        C2         C3
# 0    0.935966  2.238184  -0.487766
# 1   11.000000  1.244049   0.855190
# 2    0.245415  0.728982  -0.455924
# 3    0.145054  1.350507 -10.000000
# 4    0.399727  1.235256  -1.509374
# 5    0.143975 -0.897712  -0.409744
# 6   -0.941629  0.895621   1.004857
# 7   -0.144142 -0.860328  -0.462164
# 8   -0.165190 -1.423691   0.772646
# 9    1.265950 -1.806888   0.492586
# 10   1.385753  0.952641   0.406580
# 11  -0.935626  0.787183   1.312296
# 12   3.099833  0.706802  -0.561060
# 13   0.593319  0.203317   0.489390
# 14   1.400841 -1.448825  -1.358642
# 15   0.362736  0.270104   0.957627
# 16  -2.057598  0.819787  -1.553341
# 17  -0.040395  0.858697  -1.963303
# 18  -0.039000  0.314662   0.544651
# 19   0.974880  1.518156  -0.155925

# %%
plt.boxplot([df['C1'],df['C3']])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16255e88d10>,
#   <matplotlib.lines.Line2D at 0x16258849810>,
#   <matplotlib.lines.Line2D at 0x16258859ad0>,
#   <matplotlib.lines.Line2D at 0x1625885a610>],
#  'caps': [<matplotlib.lines.Line2D at 0x1625884a350>,
#   <matplotlib.lines.Line2D at 0x1625884ae90>,
#   <matplotlib.lines.Line2D at 0x1625885b150>,
#   <matplotlib.lines.Line2D at 0x1625885bc90>],
#  'boxes': [<matplotlib.lines.Line2D at 0x16258848190>,
#   <matplotlib.lines.Line2D at 0x16258859090>],
#  'medians': [<matplotlib.lines.Line2D at 0x1625884ba10>,
#   <matplotlib.lines.Line2D at 0x16258868810>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16258858450>,
#   <matplotlib.lines.Line2D at 0x16258849610>],
#  'means': []}

# %%
plt.scatter(x = df['C1'],y=df['C3'])
plt.grid(True)

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
d = pd.DataFrame({'date':['2020-01-03',
                          '2021-11-22','2023-01-05'],
                  'name':['J','Y','O']})

d = pd.to_datetime(d.date,format='%Y-%m-%d')
d
# Out:
# 0   2020-01-03
# 1   2021-11-22
# 2   2023-01-05
# Name: date, dtype: datetime64[ns]

# %%
df = pd.DataFrame(np.random.randn(15,3),columns=['C1','C2','C3'])
df.loc[1,'C2']=np.nan
df.loc[3,'C2']=np.nan
df
# Out:
#           C1        C2        C3
# 0   0.075133 -1.484299 -0.005420
# 1  -1.143030       NaN  0.746160
# 2   1.296518 -0.591923  0.008954
# 3   0.205247       NaN  0.220056
# 4   2.524904 -1.135027 -1.148276
# 5   0.792382  1.058058 -1.057581
# 6  -0.045984  0.034268 -1.312430
# 7   0.859974  0.750797  0.478066
# 8  -0.481916  0.483291  1.878380
# 9  -1.949838 -1.256447 -0.149609
# 10 -1.630349 -0.025483  0.028142
# 11 -0.579109 -1.290602  0.762093
# 12 -0.697926  0.066587  0.124431
# 13  1.306097 -1.609432 -0.228160
# 14 -1.583862 -0.213614 -1.168041

# %%
df = df.fillna(0)
df
# Out:
#           C1        C2        C3
# 0   0.075133 -1.484299 -0.005420
# 1  -1.143030  0.000000  0.746160
# 2   1.296518 -0.591923  0.008954
# 3   0.205247  0.000000  0.220056
# 4   2.524904 -1.135027 -1.148276
# 5   0.792382  1.058058 -1.057581
# 6  -0.045984  0.034268 -1.312430
# 7   0.859974  0.750797  0.478066
# 8  -0.481916  0.483291  1.878380
# 9  -1.949838 -1.256447 -0.149609
# 10 -1.630349 -0.025483  0.028142
# 11 -0.579109 -1.290602  0.762093
# 12 -0.697926  0.066587  0.124431
# 13  1.306097 -1.609432 -0.228160
# 14 -1.583862 -0.213614 -1.168041

# %%
df = pd.DataFrame(np.random.randn(15,3),columns=['C1','C2','C3'])
df.loc[2,'C2']=np.nan
df.loc[3,'C2']=np.nan
df
df2=df.fillna(df.mean())
df2
# Out:
#           C1        C2        C3
# 0   1.493031 -0.752803  0.566692
# 1  -0.035898 -0.072507 -0.774529
# 2   0.729292  0.076121 -0.870451
# 3  -0.794944  0.076121  1.391129
# 4  -0.886039  0.563863 -0.048147
# 5   2.466942  0.228890  0.524443
# 6   0.614978  0.181380 -0.050077
# 7  -0.055650  0.408361  1.429572
# 8   0.422060  1.059423 -1.470504
# 9  -1.263966 -0.145432 -0.253093
# 10 -0.752766 -1.211812 -1.065434
# 11 -2.545421  0.328990 -0.174218
# 12 -0.463523  0.264868 -1.425593
# 13  0.460682 -0.119651 -0.759816
# 14 -0.098613  0.256001  1.797942

# %%
data = {'학번':range(2000,2010),'성적':[85,95,75,70,100,100,95,85,80,85],'전공':['컴퓨터공학','컴퓨터공학',
                                                                               '화학공학','기계공학'
                                                                               ,'전자공학','수학교육'
                                                                               ,'건축공학','항곡시스템공학'
                                                                               ,'컴퓨터공학',np.nan]}
df=pd.DataFrame(data)
df = df.fillna(df['전공'].mode()[0])
df['전공']
# Out:
# 0      컴퓨터공학
# 1      컴퓨터공학
# 2       화학공학
# 3       기계공학
# 4       전자공학
# 5       수학교육
# 6       건축공학
# 7    항곡시스템공학
# 8      컴퓨터공학
# 9      컴퓨터공학
# Name: 전공, dtype: object

# %%
data = {'학번':range(2000,2010),'성적':[85,95,75,70,100,100,95,85,80,85],'전공':['컴퓨터공학','컴퓨터공학',
                                                                               '화학공학','기계공학'
                                                                               ,'전자공학','수학교육'
                                                                               ,'건축공학','항곡시스템공학'
                                                                               ,'컴퓨터공학',np.nan]}
df=pd.DataFrame(data)
df = df.dropna()
df
# Out:
#      학번   성적       전공
# 0  2000   85    컴퓨터공학
# 1  2001   95    컴퓨터공학
# 2  2002   75     화학공학
# 3  2003   70     기계공학
# 4  2004  100     전자공학
# 5  2005  100     수학교육
# 6  2006   95     건축공학
# 7  2007   85  항곡시스템공학
# 8  2008   80    컴퓨터공학

# %%
df = pd.DataFrame(np.random.randn(15,3),columns=['C1','C2','C3'])
df.loc[1,'C2']=11
df.loc[3,'C2']=-10
plt.boxplot([df['C1'],df['C2']])
df = df.drop((df[df.C1>10].index))
df
# Out:
#           C1         C2        C3
# 0  -1.061218   0.326363 -1.889383
# 1   0.059896  11.000000 -1.840830
# 2  -0.084661  -0.223512  0.382258
# 3   0.137329 -10.000000  0.919994
# 4  -1.207800   0.737343  1.131184
# 5   1.979505  -0.653036  0.681529
# 6   0.528075  -0.793600  0.334805
# 7   1.243801   0.798479 -0.791971
# 8   0.670375   1.928719  1.985686
# 9   1.124279   1.233514  0.113648
# 10  0.401768   0.524750 -0.785516
# 11 -1.201218  -0.168839  0.927189
# 12 -0.152038  -0.084948  0.863571
# 13  1.326220   0.043423 -0.837222
# 14 -0.526028   0.447009 -0.397792

# %%
import pandas as pd
df = pd.read_csv('data/Machine_Learning/기온과제로콜라.csv')
df.info
# Out:
# <bound method DataFrame.info of            date  mean   min   max  zero_coke
# 0    2021-09-24  21.8  16.7  26.9         58
# 1    2021-09-25  21.2  18.7  23.1         54
# 2    2021-09-26  22.6  18.4  27.3         77
# 3    2021-09-27  21.6  18.7  25.0        100
# 4    2021-09-28  21.5  19.6  24.4         77
# ..          ...   ...   ...   ...        ...
# 361  2022-09-20  19.9  16.1  24.6         21
# 362  2022-09-21  19.4  13.0  25.6         21
# 363  2022-09-22  19.8  14.2  24.7         19
# 364  2022-09-23  17.5  14.7  22.2         14
# 365  2022-09-24  18.5  12.3  24.2         13
#
# [366 rows x 5 columns]>

# %%
df.tail()
# Out:
#            date  mean   min   max  zero_coke
# 361  2022-09-20  19.9  16.1  24.6         21
# 362  2022-09-21  19.4  13.0  25.6         21
# 363  2022-09-22  19.8  14.2  24.7         19
# 364  2022-09-23  17.5  14.7  22.2         14
# 365  2022-09-24  18.5  12.3  24.2         13

# %%
df.isnull().sum()
# Out:
# date         0
# mean         0
# min          1
# max          0
# zero_coke    0
# dtype: int64

# %%
df.describe()
# Out:
#              mean         min         max   zero_coke
# count  366.000000  365.000000  366.000000  366.000000
# mean    13.556011    9.522466   18.236612   41.893443
# std     10.749479   11.146055   10.566594   16.789824
# min    -12.100000  -15.500000   -7.300000    6.000000
# 25%      5.025000    0.700000    9.300000   30.000000
# 50%     14.700000   10.400000   20.150000   44.000000
# 75%     22.875000   18.900000   27.275000   54.000000
# max     30.900000   27.400000   36.100000  100.000000

# %%
df=df.dropna(axis=0)
df.isnull().sum()
# Out:
# date         0
# mean         0
# min          0
# max          0
# zero_coke    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
df.hist(figsize=(20,10),grid=False,layout=(2,4),bins=30)
# Out:
# array([[<Axes: title={'center': 'mean'}>,
#         <Axes: title={'center': 'min'}>, <Axes: title={'center': 'max'}>,
#         <Axes: title={'center': 'zero_coke'}>],
#        [<Axes: >, <Axes: >, <Axes: >, <Axes: >]], dtype=object)

# %%
num_features = df.select_dtypes(include=[np.number]).columns
sns.pairplot(df[num_features])
# Out:
# D:\machine_learning\venv\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(20,7))
sns.heatmap(df[['mean','zero_coke']].corr(),annot=True)
# Out:
# <Axes: >

# %%
import pandas as pd
df = pd.read_csv('data/Machine_Learning/abalone.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
df.isnull().sum(
)
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# 25%          0.093500      0.130000     8.000000
# 50%          0.171000      0.234000     9.000000
# 75%          0.253000      0.329000    11.000000
# max          0.760000      1.005000    29.000000

# %%
df.mode()
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    M   0.550      0.45    0.15        0.2225           0.175
# 1  NaN   0.625       NaN     NaN           NaN             NaN
#
#    Viscera weight  Shell weight  Rings
# 0          0.1715         0.275    9.0
# 1             NaN           NaN    NaN

# %%
df = df[df.Height>0]
df.Height.min()
# Out:
# 0.01

# %%
df.groupby('Rings').count()
# Out:
#        Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# Rings
# 1        1       1         1       1             1               1
# 2        1       1         1       1             1               1
# 3       15      15        15      15            15              15
# 4       57      57        57      57            57              57
# 5      115     115       115     115           115             115
# 6      258     258       258     258           258             258
# 7      391     391       391     391           391             391
# 8      567     567       567     567           567             567
# 9      689     689       689     689           689             689
# 10     634     634       634     634           634             634
# 11     487     487       487     487           487             487
# 12     267     267       267     267           267             267
# 13     203     203       203     203           203             203
# 14     126     126       126     126           126             126
# 15     103     103       103     103           103             103
# 16      67      67        67      67            67              67
# 17      58      58        58      58            58              58
# 18      42      42        42      42            42              42
# 19      32      32        32      32            32              32
# 20      26      26        26      26            26              26
# 21      14      14        14      14            14              14
# 22       6       6         6       6             6               6
# 23       9       9         9       9             9               9
# 24       2       2         2       2             2               2
# 25       1       1         1       1             1               1
# 26       1       1         1       1             1               1
# 27       2       2         2       2             2               2
# 29       1       1         1       1             1               1
#
#        Viscera weight  Shell weight
# Rings
# 1                   1             1
# 2                   1             1
# 3                  15            15
# 4                  57            57
# 5                 115           115
# 6                 258           258
# 7                 391           391
# 8                 567           567
# 9                 689           689
# 10                634           634
# 11                487           487
# 12                267           267
# 13                203           203
# 14                126           126
# 15                103           103
# 16                 67            67
# 17                 58            58
# 18                 42            42
# 19                 32            32
# 20                 26            26
# 21                 14            14
# 22                  6             6
# 23                  9             9
# 24                  2             2
# 25                  1             1
# 26                  1             1
# 27                  2             2
# 29                  1             1

# %%
df.groupby('Rings')['Shucked weight'].mean()
# Out:
# Rings
# 3     0.011767
# 4     0.024719
# 5     0.061696
# 6     0.123158
# 7     0.182657
# 8     0.293773
# 9     0.384560
# 10    0.435632
# 11    0.483220
# 12    0.433771
# 13    0.413406
# 14    0.396779
# 15    0.399054
# 16    0.414720
# 17    0.426368
# 18    0.441878
# 19    0.440625
# 20    0.433521
# 21    0.447464
# 22    0.405000
# 23    0.399444
# 24    0.600250
# 25    0.426500
# 26    0.384000
# 27    0.539000
# 29    0.705500
# Name: Shucked weight, dtype: float64

# %%
df.groupby('Rings')[['Shucked weight','Whole weight','Shell weight']].mean()
# Out:
#        Shucked weight  Whole weight  Shell weight
# Rings
# 3            0.011767      0.028400      0.008933
# 4            0.024719      0.059605      0.018000
# 5            0.061696      0.125500      0.036770
# 6            0.123158      0.273174      0.078388
# 7            0.182657      0.397386      0.111648
# 8            0.293773      0.640753      0.178609
# 9            0.384560      0.846040      0.235241
# 10           0.435632      0.985162      0.277467
# 11           0.483220      1.103191      0.311912
# 12           0.433771      1.020251      0.302689
# 13           0.413406      1.035536      0.312388
# 14           0.396779      1.019542      0.314708
# 15           0.399054      1.031225      0.318088
# 16           0.414720      1.116174      0.373508
# 17           0.426368      1.131217      0.359934
# 18           0.441878      1.171244      0.371683
# 19           0.440625      1.166797      0.365312
# 20           0.433521      1.178813      0.401792
# 21           0.447464      1.250607      0.444643
# 22           0.405000      1.221250      0.390000
# 23           0.399444      1.170389      0.370556
# 24           0.600250      1.798750      0.632500
# 25           0.426500      1.406000      0.510000
# 26           0.384000      1.057500      0.375000
# 27           0.539000      1.698000      0.705000
# 29           0.705500      1.807500      0.475000

# %%
df.hist(figsize=(20,10),grid=False,layout=(2,4),bins=30)
# Out:
# array([[<Axes: title={'center': 'Length'}>,
#         <Axes: title={'center': 'Diameter'}>,
#         <Axes: title={'center': 'Height'}>,
#         <Axes: title={'center': 'Whole weight'}>],
#        [<Axes: title={'center': 'Shucked weight'}>,
#         <Axes: title={'center': 'Viscera weight'}>,
#         <Axes: title={'center': 'Shell weight'}>,
#         <Axes: title={'center': 'Rings'}>]], dtype=object)

# %%
import seaborn as sns
sns.countplot(x="Sex",data = df, palette="Set3")
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
plt.figure(figsize=(20,7))
sns.swarmplot(x = 'Sex',y='Rings',data=df,hue='Sex')
sns.violinplot(x = 'Sex',y='Rings',data=df)
# Out:
# D:\machine_learning\venv\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 47.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\machine_learning\venv\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 43.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\machine_learning\venv\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 49.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='Sex', ylabel='Rings'>
# D:\machine_learning\venv\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 56.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\machine_learning\venv\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 52.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# D:\machine_learning\venv\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 58.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
import numpy as np
num_features = df.select_dtypes(include=[np.number]).columns
sns.pairplot(df[num_features])
# Out:
# D:\machine_learning\venv\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.scatter(x=df['Shell weight'],y=df['Rings'])
plt.grid(True)

# %%
df.drop(df[(df['Shell weight']>0.6)&(df['Rings']<25)].index,inplace=True)
df.drop(df[(df['Shell weight']<0.8)&(df['Rings']>25)].index,inplace=True)
df.drop(df[(df['Shell weight']>0.6)&(df['Rings']>25)].index,inplace=True)
var = 'Shell weight'
plt.scatter(x= df[var],y=df['Rings'])
plt.grid()

# %%
plt.scatter(x=df['Viscera weight'],y=df['Rings'])
plt.grid(True)

# %%
df.drop(df[(df['Viscera weight']>0.5)&(df['Rings']<20)].index,inplace=True)
df.drop(df[(df['Viscera weight']<0.5)&(df['Rings']>=25)].index,inplace=True)
var = 'Viscera weight'
plt.scatter(x=df[var],y=df['Rings'])
plt.grid()

# %%
plt.scatter(x=df['Shucked weight'],y=df['Rings'])
plt.grid(True)

# %%
df.drop(df[(df['Shucked weight']>=1)&(df['Rings']<20)].index,inplace=True)
df.drop(df[(df['Shucked weight']<1)&(df['Rings']>20)].index,inplace=True)
var = 'Shucked weight'
plt.scatter(x=df[var],y=df['Rings'])
plt.grid()

# %%
plt.scatter(x=df['Whole weight'],y=df['Rings'])
plt.grid()

# %%
df.drop(df[(df['Whole weight']>2.0)&(df['Rings']<=20)].index,inplace=True)
plt.scatter(x=df['Whole weight'],y=df['Rings'])
plt.grid()

# %%
plt.scatter(x=df['Diameter'],y=df['Rings'])
plt.grid(True)

# %%
df.drop(df[(df['Diameter']<=0.1)&(df['Rings']<2.5)].index,inplace=True)
plt.scatter(x=df['Diameter'],y=df['Rings'])
plt.grid(True)

# %%
plt.scatter(x=df['Height'],y=df['Rings'])
plt.grid(True)

# %%
df.drop(df[(df['Height']>0.4)&(df['Rings']<15)].index,inplace=True)
plt.scatter(x=df['Height'],y=df['Rings'])
plt.grid()

# %%
plt.scatter(x=df['Length'],y=df['Rings'])
plt.grid()

# %%
plt.figure(figsize=(20,7))
sns.heatmap(df[num_features].corr(),annot=True)
# Out:
# <Axes: >
